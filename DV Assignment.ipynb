# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
data=pd.read_csv('Project.csv')
data
# Out:
#         transaction_id transaction_date transaction_time  store_id  \
# 0               114301       01-06-2023         11:33:29         3
# 1               115405       02-06-2023         11:18:24         3
# 2               115478       02-06-2023         12:02:45         3
# 3               116288       02-06-2023         19:39:47         3
# 4               116714       03-06-2023         12:24:57         3
# ...                ...              ...              ...       ...
# 149111          129465       14-06-2023         08:34:10         5
# 149112          133523       17-06-2023         09:55:47         8
# 149113          133674       17-06-2023         10:41:11         8
# 149114          133744       17-06-2023         11:18:31         8
# 149115          149043       30-06-2023         11:18:31         8
#
#          store_location  product_id  transaction_qty  unit_price  Total_Bill  \
# 0               Astoria          45                1        3.00         3.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149116 entries, 0 to 149115
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   transaction_id    149116 non-null  int64
#  1   transaction_date  149116 non-null  object
#  2   transaction_time  149116 non-null  object
#  3   store_id          149116 non-null  int64
#  4   store_location    149116 non-null  object
#  5   product_id        149116 non-null  int64
#  6   transaction_qty   149116 non-null  int64
#  7   unit_price        149116 non-null  float64
#  8   Total_Bill        149116 non-null  float64
#  9   product_category  149116 non-null  object
#  10  product_type      149116 non-null  object
#  11  product_detail    149116 non-null  object
#  12  Size              149116 non-null  object
#  13  Month Name        149116 non-null  object
#  14  Day Name          149116 non-null  object
#  15  Hour              149116 non-null  int64
# ...

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='product_category', y='transaction_qty', data=data)
plt.title('Transaction Quantities by Product Category')
plt.xlabel('Product Category')
plt.ylabel('Transaction Quantity')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='Month Name', y='Total_Bill', data=data.groupby('Month Name')['Total_Bill'].sum().reset_index())
plt.title('Total Bills by Month')
plt.xlabel('Month')
plt.ylabel('Total Bill')
plt.xticks(rotation=45)
plt.show()

# %%
x = data['transaction_qty']  
y = data['unit_price']       
sizes = data['Total_Bill'] 
plt.figure(figsize=(10, 8))
plt.scatter(x, y, s=sizes, alpha=0.5)
plt.title('Bubble Chart of Transaction Quantity vs. Unit Price')
plt.xlabel('Transaction Quantity')
plt.ylabel('Unit Price')
plt.colorbar(label='Total Bill')

plt.show()

# %%
column_to_plot = 'Total_Bill'
plt.figure(figsize=(10, 6))
plt.hist(data[column_to_plot], bins=30, color='skyblue', edgecolor='black')

plt.title('Histogram of Total Bill')
plt.xlabel('Total Bill')
plt.ylabel('Frequency')

plt.show()

# %%
x_column = 'transaction_qty'
y_column = 'Total_Bill'

plt.figure(figsize=(10, 6))
plt.scatter(data[x_column], data[y_column], alpha=0.5)

plt.title('Scatter Plot of Transaction Quantity vs. Total Bill')
plt.xlabel('Transaction Quantity')
plt.ylabel('Total Bill')

plt.show()

# %%
column_to_plot = 'Total_Bill'
plt.figure(figsize=(10, 6))
sns.boxplot(data=data[column_to_plot])
plt.title('Box Plot of Total Bill')
plt.xlabel('Total Bill')

plt.show()

# %%
column_to_plot = 'Total_Bill'
plt.figure(figsize=(10, 6))
sns.violinplot(data=data[column_to_plot])
plt.title('Violin Plot of Total Bill')
plt.xlabel('Total Bill')

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
column_to_plot = 'Total_Bill'
plt.figure(figsize=(10, 6))
sns.kdeplot(data[column_to_plot], shade=True)
plt.title('Density Plot of Total Bill')
plt.xlabel('Total Bill')

plt.show()
# Out:
# C:\Users\KEERTHANA.R\AppData\Local\Temp\ipykernel_8328\671247820.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data[column_to_plot], shade=True)

# %%
# !pip install wordcloud
# Out:
# ...
#      ------------------------------------ 300.0/300.0 kB 314.3 kB/s eta 0:00:00
# ...
# WARNING: There was an error checking the latest version of pip.

# %%
from wordcloud import WordCloud
text = ' '.join(data['product_detail'])

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  
plt.show()
